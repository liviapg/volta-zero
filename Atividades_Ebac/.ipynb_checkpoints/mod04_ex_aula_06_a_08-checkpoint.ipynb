# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url_municipio = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
r = requests.get(url_municipio)

# %%
r.status_code
# Out:
# 200

# %%
data_municipio = r.json()

# %%
df_municipio = pd.DataFrame(data_municipio['items'])

# %%
df_municipio.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      30348        Município  Rio de Janeiro   3304557  RJ
# 1      34031        Município        Itatiaia   3302254  RJ
# 2      28489        Município  Rio de Janeiro   3304557  RJ
# 3      12521        Município     Nova Iguaçu   3303500  RJ
# 4      13004        Município          Quatis   3304128  RJ
#
#                 num_pvl                          status          num_processo  \
# 0  PVL02.002745/2018-21                        Deferido  17944.109791/2018-12
# 1  PVL02.003023/2019-74               Deferido (PVL-IF)                  None
# 2  PVL02.000606/2018-62  Arquivado por decurso de prazo  17944.104407/2018-95
# 3                  None                        Deferido  17944.001705/2007-71
# 4                  None                        Deferido  17944.001881/2011-90
#
#          data_protocolo                tipo_operacao  \
# 0  2018-11-29T11:59:21Z  Operação contratual interna
# 1                  None  Operação contratual interna
# 2  2018-09-04T14:13:17Z  Operação contratual interna
# 3  2008-03-24T03:00:00Z  Operação contratual interna
# 4  2012-05-07T03:00:00Z  Operação contratual interna
#
#                  finalidade                      tipo_credor  \
# 0         Aporte de capital  Instituição Financeira Nacional
# 1            Infraestrutura  Instituição Financeira Nacional
# 2   Renegociação de dívidas  Instituição Financeira Nacional
# 3  PAC - Pró-Moradia - 2008  Instituição Financeira Nacional
# 4            Infraestrutura  Instituição Financeira Nacional
#
#                                            credor moeda         valor  \
# 0                   Banco Santander (Brasil) S.A.  Real  3.000000e+08
# 1                             Banco do Brasil S/A  Real  5.000000e+06
# 2                         Caixa Econômica Federal  Real  4.416492e+08
# 3                         Caixa Econômica Federal  Real  1.424795e+08
# 4  Agência de Fomento do Estado do Rio de Janeiro  Real  3.853055e+05
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  29/11/2018
# 1                 0                      1  17/10/2019
# 2                 0                      0  22/10/2019
# 3                 1                      0  27/03/2008
# 4                 1                      0  29/06/2012

# %%
df_municipio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              263 non-null    int64
#  1   tipo_interessado       263 non-null    object
#  2   interessado            263 non-null    object
#  3   cod_ibge               263 non-null    int64
#  4   uf                     263 non-null    object
#  5   num_pvl                86 non-null     object
#  6   status                 263 non-null    object
#  7   num_processo           238 non-null    object
#  8   data_protocolo         238 non-null    object
#  9   tipo_operacao          263 non-null    object
#  10  finalidade             263 non-null    object
#  11  tipo_credor            263 non-null    object
#  12  credor                 263 non-null    object
#  13  moeda                  263 non-null    object
#  14  valor                  263 non-null    float64
#  15  pvl_assoc_divida       263 non-null    int64
#  16  pvl_contradado_credor  263 non-null    int64
#  17  data_status            263 non-null    object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 37.1+ KB

# %%
# 2) Seu código aqui
(df_municipio['status']
     .value_counts()
     .head(3)
)
# Out:
# status
# Deferido        106
# Arquivado        53
# Regularizado     26
# Name: count, dtype: int64

# %%
df_municipio['data_status'].head()
# Out:
# 0    29/11/2018
# 1    17/10/2019
# 2    22/10/2019
# 3    27/03/2008
# 4    29/06/2012
# Name: data_status, dtype: object

# %%
# 3) Seu código aqui
df_municipio['ano_status_str'] = (df_municipio['data_status']
    .astype(str)
    .str[-4:]
)

# %%
# 3)  Seu código aqui
df_municipio['ano_status_dt'] = (pd
    .to_datetime(df_municipio['data_status'], format='%d/%m/%Y')
    .dt.year
)

# %%
df_municipio.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0      30348        Município  Rio de Janeiro   3304557  RJ
# 1      34031        Município        Itatiaia   3302254  RJ
# 2      28489        Município  Rio de Janeiro   3304557  RJ
# 3      12521        Município     Nova Iguaçu   3303500  RJ
# 4      13004        Município          Quatis   3304128  RJ
#
#                 num_pvl                          status          num_processo  \
# 0  PVL02.002745/2018-21                        Deferido  17944.109791/2018-12
# 1  PVL02.003023/2019-74               Deferido (PVL-IF)                  None
# 2  PVL02.000606/2018-62  Arquivado por decurso de prazo  17944.104407/2018-95
# 3                  None                        Deferido  17944.001705/2007-71
# 4                  None                        Deferido  17944.001881/2011-90
#
#          data_protocolo                tipo_operacao  \
# 0  2018-11-29T11:59:21Z  Operação contratual interna
# 1                  None  Operação contratual interna
# 2  2018-09-04T14:13:17Z  Operação contratual interna
# 3  2008-03-24T03:00:00Z  Operação contratual interna
# 4  2012-05-07T03:00:00Z  Operação contratual interna
#
#                  finalidade                      tipo_credor  \
# 0         Aporte de capital  Instituição Financeira Nacional
# 1            Infraestrutura  Instituição Financeira Nacional
# 2   Renegociação de dívidas  Instituição Financeira Nacional
# 3  PAC - Pró-Moradia - 2008  Instituição Financeira Nacional
# 4            Infraestrutura  Instituição Financeira Nacional
#
#                                            credor moeda         valor  \
# 0                   Banco Santander (Brasil) S.A.  Real  3.000000e+08
# 1                             Banco do Brasil S/A  Real  5.000000e+06
# 2                         Caixa Econômica Federal  Real  4.416492e+08
# 3                         Caixa Econômica Federal  Real  1.424795e+08
# 4  Agência de Fomento do Estado do Rio de Janeiro  Real  3.853055e+05
#
#    pvl_assoc_divida  pvl_contradado_credor data_status ano_status_str  \
# 0                 1                      0  29/11/2018           2018
# 1                 0                      1  17/10/2019           2019
# 2                 0                      0  22/10/2019           2019
# 3                 1                      0  27/03/2008           2008
# 4                 1                      0  29/06/2012           2012
#
#    ano_status_dt
# 0           2018
# 1           2019
# 2           2019
# 3           2008
# 4           2012

# %%
# 4)  Seu código aqui
(df_municipio['ano_status_str']).value_counts()
# Out:
# ano_status_str
# 2008    37
# 2007    29
# 2023    28
# 2014    20
# 2010    19
# 2019    16
# 2020    15
# 2013    15
# 2012    13
# 2022    11
# 2011    10
# 2009     9
# 2015     8
# 2024     5
# 2017     5
# 2021     5
# 2018     4
# 2016     4
# 2006     4
# 2002     4
# 2003     1
# 2004     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_api_credito(uf, tipo_interessado):
    uf = uf.upper()
    tipo_interessado = tipo_interessado.lower().capitalize()
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    r = requests.get(url)
    data_json = r.json()

    if data_json['items']:
        df = pd.DataFrame(data_json['items'])
        return df
    
    return 'Parâmetros da URL inválidos'

# %%
df_mg = consulta_api_credito('mg','estado')

# %%
df_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       5828           Estado  Minas Gerais        31  MG
# 1       7435           Estado  Minas Gerais        31  MG
# 2      68204           Estado  Minas Gerais        31  MG
# 3      13587           Estado  Minas Gerais        31  MG
# 4      13672           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2  PVL02.003861/2023-24                    Em retificação pelo interessado
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#            num_processo        data_protocolo  \
# 0  17944.000208/2013-02  2013-07-16T03:00:00Z
# 1  17944.000576/2009-66  2009-05-26T03:00:00Z
# 2  17944.001186/2024-42  2024-03-19T14:59:50Z
# 3  19405.000031/2004-78  2004-11-27T02:00:00Z
# 4  19405.000048/2005-14  2005-12-28T02:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual interna (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2                              Concessão de garantia
# 3  Operação contratual externa (com garantia da U...
# 4  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0                                     Infraestrutura
# 1                       Fortalecimento Institucional
# 2  Concessão de garantia a empresa estatal não de...
# 3                              Desenvolvimento rural
# 4                                     Multissetorial
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1  Instituição Financeira Internacional
# 2  Instituição Financeira Internacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0                                Banco do Brasil S/A           Real
# 1            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2                               New Development Bank  Dólar dos EUA
# 3  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.500000e+09                 1                      0  12/08/2013
# 1  4.000000e+07                 1                      0  10/06/2009
# 2  2.000000e+08                 0                      0  03/04/2024
# 3  3.500000e+07                 1                      0  09/12/2004
# 4  1.700000e+08                 1                      0  19/04/2006

# %%
# 2) Seu código aqui
(df_mg['status'] == 'Arquivado por decurso de prazo').sum()
# Out:
# 1

# %%
# 3) Seu código aqui
df_ba_municipio = consulta_api_credito('ba','município')

# %%
df_ba_municipio[['status','interessado']].value_counts()['Deferido']
# Out:
# interessado
# Luís Eduardo Magalhães    16
# Vitória da Conquista      12
# Lauro de Freitas          11
# Barreiras                 10
# Camaçari                  10
#                           ..
# Aracatu                    1
# Andorinha                  1
# Andaraí                    1
# Amélia Rodrigues           1
# Alcobaça                   1
# Name: count, Length: 185, dtype: int64

# %%
df_ba_municipio_deferido = df_ba_municipio.loc[df_ba_municipio['status'].eq('Deferido')]

# %%
df_ba_municipio_deferido['interessado'].mode()
# Out:
# 0    Luís Eduardo Magalhães
# Name: interessado, dtype: object

# %%
# 4) Seu código aqui
df_ba_estado = consulta_api_credito('ba','estado')

# %%
df_ba_estado.to_csv('Operacoes de credito BA.csv')
