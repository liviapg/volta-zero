# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1)seu código aqui
df_geral = pd.concat([df_mat,df_por,df_geo,df_ing,df_his,df_fis,df_qui], axis=1)
df_geral.columns = ['mat','por','geo','ing','his','fis','qui']
df_geral.div([24,18,8,8,8,12,12])
# Out:
#          mat       por    geo    ing    his       fis       qui
# 0   0.250000  0.388889  0.875  0.375  0.125  0.666667  0.250000
# 1   0.791667  0.555556  0.000  0.000  0.000  0.916667  0.666667
# 2   0.583333  0.888889  0.000  0.625  0.875  0.333333  0.333333
# 3   0.416667  0.388889  0.375  0.500  0.000  0.000000  0.666667
# 4   0.291667  0.111111  0.250  0.875  0.000  0.750000  0.250000
# ..       ...       ...    ...    ...    ...       ...       ...
# 95  0.250000  0.222222  0.875  0.125  0.500  0.750000  0.250000
# 96  0.333333  0.055556  0.500  0.750  0.125  0.333333  0.250000
# 97  0.958333  0.277778  0.000  0.250  0.500  0.083333  0.416667
# 98  0.000000  0.555556  0.375  0.125  0.625  0.833333  0.916667
# 99  0.458333  0.833333  0.000  0.125  0.750  0.583333  0.166667
#
# [100 rows x 7 columns]

# %%
# 2)seu código aqui
total = df_geral.sum(axis=1).to_frame('total')
total
# Out:
#     total
# 0      35
# 1      48
# 2      50
# 3      32
# 4      30
# ..    ...
# 95     34
# 96     27
# 97     40
# 98     40
# 99     42
#
# [100 rows x 1 columns]

# %%
# 3)seu código aqui
total.div(24+18+8+8+8+12+12)
# Out:
#        total
# 0   0.388889
# 1   0.533333
# 2   0.555556
# 3   0.355556
# 4   0.333333
# ..       ...
# 95  0.377778
# 96  0.300000
# 97  0.444444
# 98  0.444444
# 99  0.466667
#
# [100 rows x 1 columns]

# %%
# 4)seu código aqui
total_gt_45 = total[total['total'].gt(45)]
total_gt_45.count()
# Out:
# total    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1)seu código aqui
df_geral.loc[df_geral[['mat', 'fis', 'qui']].eq(0).any(axis=1)]
# Out:
#     mat  por  geo  ing  his  fis  qui
# 3    10    7    3    4    0    0    8
# 6     6    0    7    7    5    0    4
# 10   10    8    3    2    1    7    0
# 12   20    8    3    7    1    0    3
# 14    7   11    1    7    1    4    0
# 20   23   11    6    5    6    2    0
# 25    0    4    7    4    0    4    8
# 26   11   14    6    2    7    0    0
# 27   21   13    1    5    7    3    0
# 33   14    8    0    5    6    6    0
# 35   11   14    6    3    3    0   11
# 49    8    1    1    0    1    0    8
# 56    7    6    7    5    6    0    8
# 65    1    8    2    4    3    0    6
# 66    5    4    3    6    3    0   10
# 72   11   16    3    4    7    0    9
# 73    1   16    2    4    3    0   11
# 74    9   11    0    7    5    7    0
# 84   15    1    0    5    1    0    4
# 89   23   11    7    7    6    9    0
# 92   14   10    1    6    1    8    0
# 94    0    5    2    6    1    3    8
# 98    0   10    3    1    5   10   11

# %%
# 1)seu código aqui - outra alternativa
df_eliminados = df_geral.loc[
    df_geral['mat'].eq(0) |
    df_geral['fis'].eq(0) |
    df_geral['qui'].eq(0)
]
df_eliminados
# Out:
#     mat  por  geo  ing  his  fis  qui
# 3    10    7    3    4    0    0    8
# 6     6    0    7    7    5    0    4
# 10   10    8    3    2    1    7    0
# 12   20    8    3    7    1    0    3
# 14    7   11    1    7    1    4    0
# 20   23   11    6    5    6    2    0
# 25    0    4    7    4    0    4    8
# 26   11   14    6    2    7    0    0
# 27   21   13    1    5    7    3    0
# 33   14    8    0    5    6    6    0
# 35   11   14    6    3    3    0   11
# 49    8    1    1    0    1    0    8
# 56    7    6    7    5    6    0    8
# 65    1    8    2    4    3    0    6
# 66    5    4    3    6    3    0   10
# 72   11   16    3    4    7    0    9
# 73    1   16    2    4    3    0   11
# 74    9   11    0    7    5    7    0
# 84   15    1    0    5    1    0    4
# 89   23   11    7    7    6    9    0
# 92   14   10    1    6    1    8    0
# 94    0    5    2    6    1    3    8
# 98    0   10    3    1    5   10   11

# %%
# 2)seu código aqui
df_eliminados.shape[0]
# Out:
# 23

# %%
# 2)seu código aqui - outra alternativa
len(df_eliminados)
# Out:
# 23

# %%
# 3)seu código aqui
(df_eliminados[['his','geo']]
    .div(8)
    .mean(axis=1)
    .to_frame('media_his_geo')
)
# Out:
#     media_his_geo
# 3          0.1875
# 6          0.7500
# 10         0.2500
# 12         0.2500
# 14         0.1250
# 20         0.7500
# 25         0.4375
# 26         0.8125
# 27         0.5000
# 33         0.3750
# 35         0.5625
# 49         0.1250
# 56         0.8125
# 65         0.3125
# 66         0.3750
# 72         0.6250
# 73         0.3125
# 74         0.3125
# 84         0.0625
# 89         0.8125
# 92         0.1250
# 94         0.1875
# 98         0.5000

# %%
# 4)seu código aqui
total_gt_45[~total_gt_45.index.isin(df_eliminados.index)]
# Out:
#     total
# 1      48
# 2      50
# 5      50
# 7      49
# 8      58
# 17     52
# 18     50
# 24     50
# 31     54
# 36     56
# 37     52
# 39     49
# 40     47
# 42     48
# 45     48
# 48     55
# 60     48
# 62     46
# 67     46
# 70     62
# 71     53
# 77     53
# 78     66
# 81     55
# 88     50
# 93     56

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %%
# 1)seu código aqui - no site indicado para download dos dados, o arquivo referente estava dividido em 5 partes
try:
    df = pd.read_csv(arquivo, sep=';')
except:
    arquivo = 'registros de vacinacao covid ACRE parte {}.csv'
    df = pd.concat([
        pd.read_csv(arquivo.format(i), sep=';') for i in range(1, 6)
    ]).reset_index(drop=True)

# %%
list(df)
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
df.head().T
# Out:
#                                                                                           0  \
# document_id                                       4ec8a639-21c6-4849-93c2-71de387841ef-i0b0
# paciente_id                               c604d719b967aa9d85a43f3bcbb2fe4f3cd8588b8b6d83...
# paciente_idade                                                                         18.0
# paciente_dataNascimento                                                          2003-09-30
# paciente_enumSexoBiologico                                                                F
# paciente_racaCor_codigo                                                                 3.0
# paciente_racaCor_valor                                                                PARDA
# paciente_endereco_coIbgeMunicipio                                                  120035.0
# paciente_endereco_coPais                                                               10.0
# ...

# %%
df.head()
# Out:
#                                  document_id  \
# 0  4ec8a639-21c6-4849-93c2-71de387841ef-i0b0
# 1  f6a861a3-7359-42e9-ac11-e5d1a379f0c6-i0b0
# 2  5531292c-8a0b-4cc5-a579-630994b45b41-i0b0
# 3  ec453555-ae0b-4420-b703-68be64055dc6-i0b0
# 4  2637d96e-cb64-4cdd-9bc8-9268e6a64d07-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  c604d719b967aa9d85a43f3bcbb2fe4f3cd8588b8b6d83...            18.0
# 1  36e3a5f876c2f84b2ea04419f422e201af859f1b6f294f...            52.0
# 2  8374e0245a4dd58a35c87c1243f8d841e2f834e9d3526a...            40.0
# 3  856182c8ff76d90dd31344176f0da5d685cf7bdfe23b4c...             9.0
# 4  da9312b11eb4d04bf43aaea8d2dee206761e78e6c8e55d...            55.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2003-09-30                          F                      3.0
# 1              1969-06-14                          F                     99.0
# ...

# %%
df.shape[0]
# Out:
# 1930279

# %%
# 2)seu código aqui
df['paciente_id'].nunique()
# Out:
# 771000

# %%
# 3)seu código aqui
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 315616

# %%
# 3)seu código aqui - outra alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 315616

# %%
# 4)seu código aqui
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 204572

# %%
# 5)seu código aqui
df['estabelecimento_razaoSocial'].value_counts()
# Out:
# estabelecimento_razaoSocial
# PREFEITURA MUNICIPAL DE RIO BRANCO         910903
# PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL    165053
# PREFEITURA MUNICIPAL DE TARAUACA            89053
# PREFEITURA MUNICIPAL DE FEIJO               75458
# PREFEITURA MUNICIPAL DE SENA MADUREIRA      60105
#                                             ...
# 61 BIS                                         14
# CENTRO DE DIAGNOSTICOS CITOLAB LTDA            13
# PREFEITURA MUNICIPAL DE MANOEL URBANO           6
# PRFEITURA MUNICIPAL DE ACRELANDIA               3
# MARIA SUELI VALE DOS SANTOS                     1
# Name: count, Length: 63, dtype: int64

# %%
df['estabelecimento_razaoSocial'].nunique()
# Out:
# 63

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)seu código aqui
df_menor = df[df["paciente_idade"]<18].copy()
df_menor
# Out:
#                                        document_id  \
# 3        ec453555-ae0b-4420-b703-68be64055dc6-i0b0
# 11       ae79035a-8bce-46f8-b7f5-0246e4bd2493-i0b0
# 13       a44f1619-94af-41e5-8790-fac048062bb8-i0b0
# 19       ae60c445-8717-4fed-b49c-3d2624238303-i0b0
# 23       ba223337-9ae1-4652-9ffa-ba6f81220897-i0b0
# ...                                            ...
# 1930240  696f3c1e-0fa3-443d-96f4-bd3bcf5c3d3c-i0b0
# 1930241  6988375d-c320-4251-ad41-5b696faf7fb2-i0b0
# 1930254  6b5f4afe-33e1-4661-9275-18c29f2169be-i0b0
# 1930256  6bb0d5cf-eeb3-4148-b3e7-d34191cbcb54-i0b0
# 1930263  6c96eb0d-49bc-49c2-8c02-98aaa5cade68-i0b0
#
#                                                paciente_id  paciente_idade  \
# 3        856182c8ff76d90dd31344176f0da5d685cf7bdfe23b4c...             9.0
# 11       ad6d95f23127feb5295b6f02b94f30ca1fccdca76e3902...            14.0
# 13       af5b3cccffbe58b12cc320c3fd2d03a444f56cb298ac58...            15.0
# ...

# %%
# 2)seu código aqui
colunas_vacina_lista = df_menor.columns
colunas_vacina_lista
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)seu código aqui
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                       236049
# Povos Indígenas                                     22578
# Outros                                              18818
# Povos e Comunidades Tradicionais                     4126
# Trabalhadores de Saúde                               1202
# População Privada de Liberdade                        270
# Comorbidades                                          244
# Gestantes                                             228
# Pessoas com Deficiência                                40
# Puérperas                                              20
# Pessoas Institucionalizadas                            15
# Trabalhadores da Educação                              12
# Trabalhadores Industriais                               3
# Pessoas de 60 anos ou mais institucionalizadas          3
# Trabalhadores de Transporte                             1
# Pessoas em Situação de Rua                              1
# ...

# %%
# 4)seu código aqui
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor.loc[:, lista_variaveis]
df_menor_lista
# Out:
#          estabelecimento_valor  \
# 3                      6917291
# 11                     2000164
# 13                     7625855
# 19                     6917291
# 23                     6159087
# ...                        ...
# 1930240                6917291
# 1930241                3810771
# 1930254                6917291
# 1930256                5354072
# 1930263                7232489
#
#                                estabelecimento_razaoSocial  \
# 3                       PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                        PREFEITURA MUNICIPAL DE TARAUACA
# 13       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 19                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 23                 PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                                                    ...
# 1930240                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 1930241                   PREFEITURA MUNICIPAL DE TARAUACA
# ...

# %%
colunas_estabelecimento_lista = colunas_vacina_lista[colunas_vacina_lista.str.startswith('estabelecimento')]
colunas_estabelecimento_lista
# Out:
# Index(['estabelecimento_valor', 'estabelecimento_razaoSocial',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf'],
#       dtype='object')

# %%
# 5)seu código aqui
df_menor_estabelecimentos = df_menor.loc[:, colunas_estabelecimento_lista]
df_menor_estabelecimentos
# Out:
#          estabelecimento_valor  \
# 3                      6917291
# 11                     2000164
# 13                     7625855
# 19                     6917291
# 23                     6159087
# ...                        ...
# 1930240                6917291
# 1930241                3810771
# 1930254                6917291
# 1930256                5354072
# 1930263                7232489
#
#                                estabelecimento_razaoSocial  \
# 3                       PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                        PREFEITURA MUNICIPAL DE TARAUACA
# 13       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 19                      PREFEITURA MUNICIPAL DE RIO BRANCO
# 23                 PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                                                    ...
# 1930240                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 1930241                   PREFEITURA MUNICIPAL DE TARAUACA
# ...

# %%
# 6)seu código aqui
df_menor_estabelecimentos = df_menor_estabelecimentos.drop_duplicates()
df_menor_estabelecimentos
# Out:
#          estabelecimento_valor  \
# 3                      6917291
# 11                     2000164
# 13                     7625855
# 23                     6159087
# 29                     3810771
# ...                        ...
# 824739                 5360080
# 900715                 9846433
# 909715                 3595943
# 1190675                3591018
# 1503855                7448627
#
#                                estabelecimento_razaoSocial  \
# 3                       PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                        PREFEITURA MUNICIPAL DE TARAUACA
# 13       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 23                 PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 29                        PREFEITURA MUNICIPAL DE TARAUACA
# ...                                                    ...
# 824739        PREFEITURA MUNICIPAL DE DE PLACIDO DE CASTRO
# 900715               PREFEITURA MUNICIPAL DE MANOEL URBANO
# ...
